# %%
import xml.etree.ElementTree as etree

filename = 'LRG_292.xml'
#assert filename=='*.xml'
tree = etree.parse(filename)
root = tree.getroot()

#create a variable to count the number of exons that we find in the xml file that we actually 
numberofexons=0

#create a filter which will select only the coordinates from the transcript entries within the exon tags.
for id in root.iter('id'):
    filt=id.text
    print filt

#create a function which saves the sequence
for child in root:
    #filter for fixed annotation
    if child.tag =='fixed_annotation':
        for gchild in child:
            # filter for the tag sequence
            if gchild.tag=='sequence':
                    #store the sequence in a string to variable sequencedata
                    sequencedata=str(gchild.text)
print sequencedata

#the following nested routine goes through the levels of xml files:
print "Root",root.attrib
for child in root:
    # filter to only look within fixed annotation
    if child.tag =='fixed_annotation':
        #print "\t tag=", child.tag 
        for gchild in child:
           for ggchild in gchild:
                #select only exons
                if ggchild.tag=='exon':
                    # each time a exon tag is selected increase count by 1
                    numberofexons=numberofexons+1
                    #print "\t\t\t tag=", ggchild.tag
                    for gggchild in ggchild:
                        #use the variable filt to select the coordinates for the transcript selected eg genomic vs transcript vs translated
                        if gggchild.attrib['coord_system'] == filt:
                            #print "\t\t\t\t tag=", gggchild.tag  
                            #print "\t\t\t\t", gggchild.attrib
                            #print "\t\t\t\t start=", gggchild.attrib ['start']
                            #print "\t\t\t\t stop=", gggchild.attrib ['end']
                            exon_start=gggchild.attrib ['start']
                            exon_end=gggchild.attrib ['end']
                            print ggchild.attrib['label'], exon_start, exon_end
                            
                        
print "number of exons:",n
# Out:
# LRG_292
# ...
# Root {'schema_version': '1.8'}
# 1 92501 92713
# 2 93869 93967
# 3 102205 102258
# 4 111451 111528
# 5 113028 113116
# 6 113723 113862
# 7 118104 118209
# 8 120695 120740
# 9 122062 122138
# 10 123124 126549
# 11 126952 127040
# 12 135409 135580
# 13 141370 141496
# 14 143463 143653
# 15 146746 147056
# 16 150289 150376
# 17 154033 154110
# 18 154611 154651
# 19 160849 160932
# 20 166867 166921
# 21 168790 168863
# 22 170281 170341
# 23 172182 173689
# number of exons: 23
